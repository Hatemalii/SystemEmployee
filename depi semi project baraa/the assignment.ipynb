# %%
import pandas as pd
import numpy as np 
import matplotlib as plt

# %%
df = pd.read_csv(r'C:\Users\hatem\Coding\Microsoft VS Code\my codes\depi semi project baraa\googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# Data Cleaning

# %%
df.sample(5)
# Out:
#                                                 App          Category  Rating  \
# 3188                              American Airlines  TRAVEL_AND_LOCAL     3.7
# 7695                         Ditto CP Calculator GO             TOOLS     4.3
# 6125                                 XXX DISTILLERY          BUSINESS     4.2
# 2165                        RISK: Global Domination            FAMILY     4.0
# 6997  Color By Number - Sandbox Pixel Coloring Book            FAMILY     4.7
#
#      Reviews                Size    Installs  Type Price Content Rating  \
# 3188   16980  Varies with device  5,000,000+  Free     0       Everyone
# 7695      34                 12M      1,000+  Free     0       Everyone
# 6125     509                3.2M    100,000+  Free     0       Everyone
# 2165   68559                 75M  5,000,000+  Free     0       Everyone
# 6997   24557                 24M  1,000,000+  Free     0       Everyone
#
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
mean_value=df['Rating'].mean()
print(mean_value)
# Out:
# 4.193338315362443

# %%
df['Rating'].sample(7)
# Out:
# 5413     4.5
# 10392    3.7
# 6689     NaN
# 9332     3.1
# 3075     3.5
# 9488     4.3
# 8673     4.7
# Name: Rating, dtype: float64

# %%
df['Rating'] = df['Rating'].fillna(mean_value)
df['Rating']
# Out:
# 0        4.100000
# 1        3.900000
# 2        4.700000
# 3        4.500000
# 4        4.300000
#            ...
# 10836    4.500000
# 10837    5.000000
# 10838    4.193338
# 10839    4.500000
# 10840    4.500000
# Name: Rating, Length: 10841, dtype: float64

# %%
print("The new mean of Rating is ",df['Rating'].mean())
df["Rating"].isnull().sum()
# Out:
# The new mean of Rating is  4.193338315362443
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Size'].sample(50)
# Out:
# 9916                   970k
# 8017                   269k
# 5779     Varies with device
# 7377                    46M
# 254                     28M
# 1569                   5.0M
# 9636     Varies with device
# 4907                    23M
# 1521                   232k
# 1604                   6.8M
# 698                    9.3M
# 10101                   19M
# 9575     Varies with device
# 3886                    14M
# 8208                   2.8M
# 8096                   8.1M
# 6712                    72M
# 9363                   7.0M
# 7600                    24M
# 6670                    14M
# 6389                   2.1M
# 5905                   4.7M
# 8777                    46M
# 3676     Varies with device
# 8905                   4.7M
# 9722                    23M
# 8980                    30M
# 7035                    11M
# 10224                   10M
# 6124                   8.1M
# 3700     Varies with device
# 7774                   1.7M
# 4418                   930k
# ...

# %%
def convert_to_kb(size):
    if 'M' in size:
        return float(size.replace('M',' ')) * 1024
    elif 'k' in size:
        return float(size.replace('k',''))
    else:
        return None

# %%
df['Updated_Size'] = df['Size'].apply(convert_to_kb)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.sample(20)
# Out:
#                                                      App            Category  \
# 7013     Tattoo Color By Number Draw Book Page Pixel Art              FAMILY
# 8448                           Story Saver for Instagram         PHOTOGRAPHY
# 1746   Block Craft 3D: Building Simulator Games For Free                GAME
# 5317                                  Alabama Road Trips    TRAVEL_AND_LOCAL
# 8252                               Ultimate DC Challenge                GAME
# 5478                                  Fate GO Ap Counter               TOOLS
# 6174                                            BG-FLEET               TOOLS
# 10101                                          Amleen Ey              SOCIAL
# 8603                                           DN Prasad             FINANCE
# 7636                                   Co-op Connections            SHOPPING
# 8833                                          DS-11 form            BUSINESS
# ...

# %%
df['Updated_Size'] = df['Updated_Size'].fillna(mean_value)
df['Updated_Size']
# Out:
# 0        19456.000000
# 1        14336.000000
# 2         8908.800000
# 3        25600.000000
# 4         2867.200000
#              ...
# 10836    54272.000000
# 10837     3686.400000
# 10838     9728.000000
# 10839        4.193338
# 10840    19456.000000
# Name: Updated_Size, Length: 10841, dtype: float64

# %%
df['Price'].sample(25)
# Out:
# 4922     0
# 7914     0
# 177      0
# 7608     0
# 8428     0
# 10715    0
# 1643     0
# 904      0
# 3991     0
# 10112    0
# 588      0
# 5273     0
# 7573     0
# 4659     0
# 9582     0
# 3936     0
# 9562     0
# 1102     0
# 7739     0
# 10809    0
# 7528     0
# 6223     0
# 3451     0
# 1007     0
# 1572     0
# Name: Price, dtype: object

# %%
df['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 10841 non-null  object
# dtypes: object(1)
# memory usage: 84.8+ KB

# %%
def remove_dollarSign(price):
    if '$' in price:
        return float(price.replace('$',' '))
    else:
        return None

# %%
df["Price"]=df['Price'].apply(remove_dollarSign)
df.sample(20)
# Out:
#                                                      App             Category  \
# 10326                          Comunidad De Fe Minitries            LIFESTYLE
# 9604                              Texas Holdem Poker Pro                 GAME
# 1161                                   Huntington Mobile              FINANCE
# 1778   Block Craft 3D: Building Simulator Games For Free                 GAME
# 6461                               DMR BrandMeister Tool        COMMUNICATION
# 3606    Listen to the story~The Story of the Fairy Tales            PARENTING
# 9779       The NBC App - Watch Live TV and Full Episodes               FAMILY
# 5658     view.com.au - Buy, Rent or Research Real Estate            LIFESTYLE
# 6430                                          BL Carrier             BUSINESS
# 2551                      Social network all in one 2018               SOCIAL
# 885                                     BBC Media Player        ENTERTAINMENT
# ...

# %%
df['Price']=df['Price'].fillna(0)
df['Price'].sample(20)
# Out:
# 1122      0.00
# 188       0.00
# 4354      0.00
# 2407     24.99
# 8375      0.00
# 3042      0.00
# 4356      0.00
# 2957      0.00
# 5357    379.99
# 2998      0.00
# 7381      0.00
# 799       0.00
# 8461      0.00
# 5621      0.00
# 318       0.00
# 1601      0.00
# 3770      0.00
# 289       0.00
# 5389      0.00
# 993       0.00
# Name: Price, dtype: float64

# %%
df['Category'].sample(20)
# Out:
# 1102                FINANCE
# 7324     NEWS_AND_MAGAZINES
# 9901                   GAME
# 9066                MEDICAL
# 8754         FOOD_AND_DRINK
# 3577              PARENTING
# 8328            PHOTOGRAPHY
# 10808             LIFESTYLE
# 1254         FOOD_AND_DRINK
# 709               EDUCATION
# 8208                  TOOLS
# 3976              LIFESTYLE
# 1865                   GAME
# 7359                  TOOLS
# 1043                 EVENTS
# 10421                FAMILY
# 9697                 FAMILY
# 2967                 SPORTS
# 3267                  TOOLS
# 9616                   GAME
# Name: Category, dtype: object

# %%
# !pip install scikit-learn
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\hatem\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...

# %%
df['Category'] = LE.fit_transform(df['Category'])
df.sample(20)
# Out:
#                                                     App  Category    Rating  \
# 10758                     Fingerprint Lock Screen Prank        30  4.100000
# 4375                      Libre Scan (Diabetes:M addon)        21  2.400000
# 9975                        Home Workout - No Equipment        16  4.800000
# 10374                                 Police Car Driver        15  3.800000
# 4954   Adblock Plus for Samsung Internet - Browse safe.         7  4.000000
# 2882                                   MIX by Camera360        25  4.400000
# 6054     BeautyPlus - Easy Photo Editor & Selfie Camera        25  4.400000
# 10637             Gainesville Florida Police Department        19  4.800000
# 5701                                       AV Tools Pro        30  4.300000
# 4967                         Ez Screen Recorder (no ad)        32  4.700000
# 1968                                       Block Puzzle        15  4.600000
# ...

# %%
df.sample(20)
# Out:
#                                                      App  Category    Rating  \
# 3233                                   Moto File Manager        30  4.100000
# 7439                          CJ Wilson's ZoomZoomnation        26  4.000000
# 8957                                DV Lottery Simulator        12  4.600000
# 5820                                       Ax 3 Domaines        29  4.500000
# 657                                     French Chat Room         8  4.200000
# 3123                                  Southwest Airlines        31  3.900000
# 9905                                         Eu sou Rico        13  4.193338
# 6971                                   Super Jabber Jump        15  4.300000
# 801    Rosetta Stone: Learn to Speak & Read New Langu...         9  4.500000
# 2091                         Dog Run - Pet Dog Simulator        12  4.700000
# 4505                                Q Link Wireless Zone        26  4.000000
# ...

# %%
df['Android Ver'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Android Ver
# Non-Null Count  Dtype
# --------------  -----
# 10838 non-null  object
# dtypes: object(1)
# memory usage: 84.8+ KB

# %%
df['Android Ver'].sample(20)
# Out:
# 2701           4.0.3 and up
# 8793           4.0.3 and up
# 4280             4.1 and up
# 3998             2.1 and up
# 3531             4.0 and up
# 8935             4.0 and up
# 7396             2.0 and up
# 7854             4.0 and up
# 2483           4.0.3 and up
# 10665            4.0 and up
# 5553             7.0 and up
# 663              5.0 and up
# 3565     Varies with device
# 9637             4.1 and up
# 3095             4.2 and up
# 4774             4.4 and up
# 7056           4.0.3 and up
# 9787             2.2 and up
# 2502           4.0.3 and up
# 8191             2.3 and up
# Name: Android Ver, dtype: object

# %%
def clean_android_version(version):
    if 'Varies with device' in version:
        return None
    else:
        return float(version.split()[0])
df['Android Ver']  = df['Android Ver'].apply(clean_android_version)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 6
#       4     else:
#       5         return float(version.split()[0])
# ----> 6 df['Android Ver']  = df['Android Ver'].apply(clean_android_version)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
# ...

# %%
x=df['Android Ver']
x
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10836            4.1 and up
# 10837            4.1 and up
# 10838            2.2 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10841, dtype: object

# %%
df.drop(columns=['Android Ver'], inplace=True)
df
# Out:
#                                                      App  Category    Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook         1  4.100000
# 1                                    Coloring book moana         1  3.900000
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...         1  4.700000
# 3                                  Sketch - Draw & Paint         1  4.500000
# 4                  Pixel Draw - Number Art Coloring Book         1  4.300000
# ...                                                  ...       ...       ...
# 10836                                   Sya9a Maroc - FR        12  4.500000
# 10837                   Fr. Mike Schmitz Audio Teachings        12  5.000000
# 10838                             Parkinson Exercices FR        21  4.193338
# 10839                      The SCP Foundation DB fr nn5n         4  4.500000
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology        19  4.500000
#
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Updated_Size      0
# dtype: int64

# %%
df['Type'].sample(20)
# Out:
# 4298     Free
# 8785     Paid
# 3665     Free
# 10590    Free
# 8787     Paid
# 4044     Free
# 4492     Free
# 1214     Free
# 7445     Free
# 8780     Paid
# 9047     Free
# 5718     Free
# 1121     Free
# 4332     Free
# 8518     Free
# 7328     Paid
# 10621    Free
# 5331     Free
# 7255     Paid
# 10092    Free
# Name: Type, dtype: object

# %%
#df[df['Type'].isna()]
df[df['Type'].isnull()]
# Out:
#                             App  Category    Rating Reviews  \
# 9148  Command & Conquer: Rivals        12  4.193338       0
#
#                     Size Installs Type  Price Content Rating    Genres  \
# 9148  Varies with device        0  NaN    0.0   Everyone 10+  Strategy
#
#        Last Updated         Current Ver  Updated_Size
# 9148  June 28, 2018  Varies with device      4.193338

# %%
df.dropna(subset=['Type'],inplace=True)
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Updated_Size      0
# dtype: int64

# %%
df.dropna(subset=['Content Rating'],inplace=True)
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Updated_Size      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10839 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  int64
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  object
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Updated_Size    10839 non-null  float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df['Current Ver'] = df['Current Ver'].fillna('0.0')

# %%
def toNumeric(y):
    if not isinstance(y, str):  # If already a number, return it
        return 0.0
    
    y = y.lower().strip()  # Normalize the string
    if "varies" in y:
        return 0.0  # Handle "Varies with device"
    
    # Extract numeric part (digits and dots only)
    num_part = ''.join(c if c.isdigit() or c == '.' else '' for c in y)
    
    try:
        return float(num_part)  # Convert to float
    except ValueError:
        return 0.0  # Default to 0.0 if conversion fails

# %%
df['Current Ver'].sample(20)
# Out:
# 635                     1.3
# 4621                    1.2
# 2905     Varies with device
# 2451                    1.0
# 10070                 1.2.6
# 393      Varies with device
# 8520                  1.0.5
# 1012                   1.40
# 237                   3.2.1
# 4046                   1.01
# 7156                  0.9.0
# 428                  5.85.1
# 10469                 4.2.1
# 5392     Varies with device
# 10597                 3.8.0
# 2505                    1.1
# 2673                  6.0.4
# 9203                    1.0
# 3168                 4.0.21
# 1686                    3.5
# Name: Current Ver, dtype: object

# %%
print(df['Current Ver'].apply(toNumeric))
# Out:
# 0    1.3000
# 1    1.2000
# 2    0.0000
# 3    1.0000
# 4    0.0000
# 5    0.0000
# 6    0.0000
# 7    1.4000
# 8    0.0000
# 9    2.2002
# Name: Current Ver, dtype: float64

# %%
df['Current Ver'] = df['Current Ver'].apply(toNumeric)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  int64
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10841 non-null  float64
#  12  Android Ver     10838 non-null  object
#  13  Updated_Size    10841 non-null  float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df['App'].sample(30)
# Out:
# 3761                                Spreaker Podcast Radio
# 8046                                 ACTIVEON CX & CX GOLD
# 8047                                      CX North America
# 6646                                     Bar-B-Q Rib House
# 6278                                  bi-Cube Mobile Token
# 7425                               Gold Teeth Photo Editor
# 2537                           Banfield Pet Health Tracker
# 6670                                 Texas Bar-B-Q Rewards
# 3834                                               Compass
# 5641                           Five Nights at Freddy's: SL
# 2041                                        Bubble Shooter
# 8124                        foody Cyprus - online ordering
# 7891                              CT Pulmonary Angiography
# 10679                                           Solitaire+
# 1152                                                GoBank
# 5676                                           news.com.au
# ...

# %% [markdown]
# Analytical questions

# %%
expensive_app = df['Price'].max()
print("THe expensive app is ",expensive_app)
# Out:
# THe expensive app is  400.0

# %%
df
# Out:
#                                                      App  Category    Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook         1  4.100000
# 1                                    Coloring book moana         1  3.900000
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...         1  4.700000
# 3                                  Sketch - Draw & Paint         1  4.500000
# 4                  Pixel Draw - Number Art Coloring Book         1  4.300000
# ...                                                  ...       ...       ...
# 10836                                   Sya9a Maroc - FR        12  4.500000
# 10837                   Fr. Mike Schmitz Audio Teachings        12  5.000000
# 10838                             Parkinson Exercices FR        21  4.193338
# 10839                      The SCP Foundation DB fr nn5n         4  4.500000
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology        19  4.500000
#
# ...

# %%
df['Genres'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Genres
# Non-Null Count  Dtype
# --------------  -----
# 10841 non-null  object
# dtypes: object(1)
# memory usage: 84.8+ KB

# %% [markdown]
# Which genre has the highest number of apps?

# %%
df['Genres'].value_counts().head(3)
# Out:
# Genres
# Tools            842
# Entertainment    623
# Education        549
# Name: count, dtype: int64

# %% [markdown]
# What is the average size of free vs. paid apps?

# %%
df['Updated_Size'].sample(25)
# Out:
# 8565      3379.200000
# 1619      4608.000000
# 4959     20480.000000
# 8377     34816.000000
# 6363      3276.800000
# 6574     16384.000000
# 5511     12288.000000
# 6381      3174.400000
# 3928         4.193338
# 7621     75776.000000
# 3994     75776.000000
# 1855     93184.000000
# 852      45056.000000
# 4535     63488.000000
# 3352         4.193338
# 150       2867.200000
# 5270      3993.600000
# 6354      4710.400000
# 3543      4300.800000
# 10049    88064.000000
# 7731      3481.600000
# 6864      2867.200000
# 4603     26624.000000
# 5397     58368.000000
# 3826     44032.000000
# Name: Updated_Size, dtype: float64

# %%
df
# Out:
#                                                      App  Category    Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook         1  4.100000
# 1                                    Coloring book moana         1  3.900000
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...         1  4.700000
# 3                                  Sketch - Draw & Paint         1  4.500000
# 4                  Pixel Draw - Number Art Coloring Book         1  4.300000
# ...                                                  ...       ...       ...
# 10836                                   Sya9a Maroc - FR        12  4.500000
# 10837                   Fr. Mike Schmitz Audio Teachings        12  5.000000
# 10838                             Parkinson Exercices FR        21  4.193338
# 10839                      The SCP Foundation DB fr nn5n         4  4.500000
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology        19  4.500000
#
# ...

# %%
df.groupby('Type')['Updated_Size'].mean()
# Out:
# Type
# 0           4.193338
# Free    18645.391147
# Paid    17892.153367
# Name: Updated_Size, dtype: float64

# %%
df['Rating']
# Out:
# 0        4.100000
# 1        3.900000
# 2        4.700000
# 3        4.500000
# 4        4.300000
#            ...
# 10836    4.500000
# 10837    5.000000
# 10838    4.193338
# 10839    4.500000
# 10840    4.500000
# Name: Rating, Length: 10841, dtype: float64

# %%
perfect_rating_apps = df[df['Rating']==5]
print(perfect_rating_apps)

# %%
print(perfect_rating_apps)
# Out:
#                                               App  Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks         6     5.0      15
# 612                 American Girls Mobile Numbers         8     5.0       5
# 615                                  Awake Dating         8     5.0       2
# 633                         Spine- The dating app         8     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat         8     5.0       6
# ...                                           ...       ...     ...     ...
# 10721                           Mad Dash Fo' Cash        15     5.0      14
# 10742                       GKPB FP Online Church        19     5.0      32
# 10776                            Monster Ride Pro        15     5.0       1
# 10820                             Fr. Daoud Lamei        12     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings        12     5.0       4
#
# ...

# %%
top_expensive = perfect_rating_apps.nlargest(5,'Price')[['App','Price','Rating']]

# %%
top_expensive
# Out:
#                                             App  Price  Rating
# 5489                  AP Art History Flashcards  29.99     5.0
# 7477                 USMLE Step 2 CK Flashcards  19.99     5.0
# 5246                      Hey AJ! It's Bedtime!   4.99     5.0
# 5482                 meStudying: AP English Lit   4.99     5.0
# 7204  TI-84 CE Graphing Calculator Manual TI 84   4.99     5.0

# %%
df['Reviews'].nlargest().head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df['Reviews'].nlargest().head(5)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4252, in Series.nlargest(self, n, keep)
#    4154 def nlargest(
#    4155     self, n: int = 5, keep: Literal["first", "last", "all"] = "first"
#    4156 ) -> Series:
#    4157     """
#    4158     Return the largest `n` elements.
#    4159
#    (...)
#    4250     dtype: int64
#    4251     """
# -> 4252     return selectn.SelectNSeries(self, n=n, keep=keep).nlargest()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\methods\selectn.py:57, in SelectN.nlargest(self)
#      55 @final
#      56 def nlargest(self):
# ...

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
num_apps_50KREV = (df['Reviews'] > 50000).sum()
num_apps_50KREV
# Out:
# 2782

# %%
avg_price_by_genre_installs = df.groupby(['Genres', 'Installs'])['Price'].mean().reset_index()

print(avg_price_by_genre_installs)
# Out:
#      Genres     Installs     Price
# 0    Action       1,000+  0.372500
# 1    Action   1,000,000+  0.320357
# 2    Action          10+  0.000000
# 3    Action      10,000+  1.871875
# 4    Action  10,000,000+  0.012532
# ..      ...          ...       ...
# 917    Word   5,000,000+  0.000000
# 918    Word          50+  0.000000
# 919    Word      50,000+  0.000000
# 920    Word  50,000,000+  0.000000
# 921    Word         500+  0.000000
#
# [922 rows x 3 columns]
